# %% [markdown]
# <a href="https://colab.research.google.com/github/orchid-initiative/postpartum-larc/blob/main/code/run_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
# !git clone https://github.com/orchid-initiative/postpartum-larc.git
# Out:
# Cloning into 'postpartum-larc'...
# remote: Enumerating objects: 568, done.
# remote: Counting objects: 100% (173/173), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 568 (delta 78), reused 35 (delta 22), pack-reused 395 (from 1)
# Receiving objects: 100% (568/568), 479.91 KiB | 4.44 MiB/s, done.
# Resolving deltas: 100% (317/317), done.

# %%
# !ls
# Out:
# postpartum-larc  sample_data

# %%
# %cd postpartum-larc
# Out:
# /content/postpartum-larc

# %%
# !ls
# Out:
# analysis  code	documentation  LICENSE	README.md

# %%
# %cd code
# Out:
# /content/postpartum-larc/code

# %%
# !ls
# Out:
# call.lg1  _flag_and_output.py  parameters.py	      _subset_inputdata.py
# call.lg2  _get_mappings.py     _readin_and_report.py
# call.py   output_from_log.txt  run_on_colab.ipynb

# %%
# %cd /content/postpartum-larc
# Out:
# /content/postpartum-larc

# %%
# !mkdir -p raw
# !mkdir -p created

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

data_path = "/content/drive/MyDrive/Immediate Post-Partum LARC Utilization/sample -- RECORD LEVEL -- output"

os.listdir(data_path)
# Out:
# ['sample_2018.csv',
#  'sample_2019.csv',
#  'sample_2020.csv',
#  'sample_2021.csv',
#  'sample_2022.csv',
#  'sample_2023.csv',
#  'sample_2024.csv',
#  'samples_combined.gsheet',
#  'sample_2024.gsheet']
