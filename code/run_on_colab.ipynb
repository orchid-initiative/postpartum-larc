# %% [markdown]
# <a href="https://colab.research.google.com/github/orchid-initiative/postpartum-larc/blob/main/code/run_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os

print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/orchid-initiative/postpartum-larc.git
# Out:
# Cloning into 'postpartum-larc'...
# remote: Enumerating objects: 592, done.
# remote: Counting objects: 100% (197/197), done.
# remote: Compressing objects: 100% (167/167), done.
# remote: Total 592 (delta 93), reused 35 (delta 22), pack-reused 395 (from 1)
# Receiving objects: 100% (592/592), 485.56 KiB | 6.39 MiB/s, done.
# Resolving deltas: 100% (332/332), done.

# %%
REPO_PATH = "/content/postpartum-larc"
CODE_PATH = f"{REPO_PATH}/code"

# %%
# Project Configuration

DATA_PATH = "/content/drive/MyDrive/Immediate Post-Partum LARC Utilization/sample -- RECORD LEVEL -- output"
OUTPUT_PATH = "/content/drive/MyDrive/Immediate Post-Partum LARC Utilization/sample aggregations"

INPUT_FILES = [
    "sample_2018.csv",
    "sample_2019.csv",
    "sample_2020.csv",
    "sample_2021.csv",
    "sample_2022.csv",
    "sample_2023.csv",
    "sample_2024.csv",
]

FILTER_VARIABLE = "MSDRG"

FILTER_VALUES = [768, 788, 807]

# %%
os.makedirs(OUTPUT_PATH, exist_ok = True)

print(OUTPUT_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_824/902922620.py in <cell line: 0>()
# ----> 1 os.makedirs(OUTPOT_PATH, exist_ok = True)
#       2
#       3 print(OUTPUT_PATH)
#
# NameError: name 'OUTPOT_PATH' is not defined

# %%
# NEXT STEPS:
# make a colab_parameters.py file with the parameters needed to change in order to
# run the program in a colab notebook
#
# change call.py so that it can accept a --parameters optional argument in order
# to run it in colab
